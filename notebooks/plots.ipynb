# %%
import sys
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas import DataFrame as df
sys.path.append("../")
from src.data import *
from src.features import *

numcols = feature_cols_numeric
numcols.append("G3")

d = Data()
data = d.data
df = data[numcols]

plt.figure(figsize=(8, 6))
corr = df.corr()

sns.heatmap(corr, annot=True, cmap='coolwarm', center=0)
plt.title("Correlation Heatmap of Numeric Features")
plt.show()

y = data["G3"]
y_labeled = grade_to_pass_fail(y)

sns.countplot(x=y_labeled, palette='pastel')
plt.title('Target Distribution')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()
# Out:
# /tmp/ipykernel_13233/2221022693.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=y_labeled, palette='pastel')
# /home/josh/school/cs4120/cs4120-project/.venv/lib64/python3.13/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/josh/school/cs4120/cs4120-project/.venv/lib64/python3.13/site-packages/seaborn/categorical.py:1273: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(aggregator, agg_var)
# /home/josh/school/cs4120/cs4120-project/.venv/lib64/python3.13/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/josh/school/cs4120/cs4120-project/.venv/lib64/python3.13/site-packages/seaborn/categorical.py:1273: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(aggregator, agg_var)
